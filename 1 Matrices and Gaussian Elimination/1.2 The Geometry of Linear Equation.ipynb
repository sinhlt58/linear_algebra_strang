# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 1

# %%
# x  + y  = 4
# 2x - 2y = 4

x1 = np.linspace(0, 7)
y1 = 4 - x1

x2 = np.linspace(0, 7)
y2 = -2 + x2

plt.plot(x1, y1)
plt.plot(x2, y2)
plt.xlabel('x')
plt.ylabel('y')
plt.grid()

# %%
V = np.array([[1*3, 2*3], [1, -2], [4, 4]])
origin = [0], [0]

plt.quiver(*origin, V[:,0], V[:,1], color=['g', 'b', 'r'], scale=22)

# %% [markdown]
# # 2

# %% [markdown]
# $ u − v − w = b1$<br>
# $     v + w = b2$<br>
# $         w = b3$<br>
#
# $w = b3$<br>
# $v = b2 - b3$<br>
# $u = b1 + b2$

# %% [markdown]
# $(b1+b2)\begin{bmatrix} 1 \\ 0 \\ 0 \\ \end{bmatrix} + (b2-b3)\begin{bmatrix} -1 \\ 1 \\ 0 \\ \end{bmatrix} + b3\begin{bmatrix} -1 \\ 1 \\ 1 \\ \end{bmatrix} = \begin{bmatrix} b1 \\ b2 \\ b3 \\ \end{bmatrix}$

# %% [markdown]
# $
#     \begin{align}
#         x + y + z &= b1\\
#             y + z &= b2\\
#                 z &= b3
#     \end{align}
# $

# %% [markdown]
# # 3
#
# $
#     \begin{align}
#         u + v + w + z &= 6 \\
#         u +     w + z &= 4 \\
#         u +     w     &= 2
#     \end{align}
# $<br>
# $
# \begin{align}
#     z = 2 \\
#     v = 2 \\
#     u + w = 2 \\
#     ==> "line"
# \end{align}
# $<br>
# $u = 1$ => a point
# Add $u + w = 3$ equation => mo solution

# %% [markdown]
# # 4
# $
#     \begin{align}
#         x + 2y &= 2 \\
#         x - y &= 2 \\
#         y &= 1
#     \end{align}
# $
#
# => not solvable
# if the right handside is 0 => $x=0,\; y=0$
#
# $y=a$ => $x = b + a$, $x = c - 2a$
#
# => b + a = c - 2a
#
# => c - b = 3a
#
# pick a = 1, c = 4, b = 1 => we have three lines intersect at a point
#
# $
#     \begin{align}
#         x + 2y &= 4 \\
#         x - y &= 1 \\
#         y &= 1
#     \end{align}
# $

# %% [markdown]
# # 5
# $
# \begin{align}
#     t &= 0 \\
#     z &= 0 \\
#     x + y + z + t &= 1
# \end{align}
# $
#
# => $x + y = 1$ => choose $x=1, y=0$ and $x=2, y=-1$

# %% [markdown]
# # 6

# %%
from mpl_toolkits.mplot3d import Axes3D

soa = np.array([
    [0, 0, 0, 1, 2, 3],
    [0, 0, 0, 1, 0, 1],
    [0, 0, 0, 1, 3, 4],
    [0, 0, 0, 2, 5, 6]
])
X, Y, Z, U, V, W = zip(*soa)

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.quiver(X, Y, Z, U, V, W)

# %% [markdown]
# $
#     \begin{align}
#         u + v + w &= 0 \\
#         2u + 3w &= 0 \\
#         3u + v + 4w &= 0
#     \end{align}
# $
#
# ==>
#
# $v = -3u - 4w$
#
# $u = \frac{-3w}{2}$
#
# $v = \frac{w}{2}$

# %% [markdown]
# w = 2 => u = -3, v = 1
# (-3, 1, 2)

# %% [markdown]
# # 7
#
# u + v = x
#
# 2u = y
#
# 3u + v = z
#
# u = 1, v = 1 => (2, 2, 4)
#
# (2, 2, 5)
#
# u + v = 2
#
# 2u = 2
#
# 3u + v = 5
#
# u = 1 => v=1
#
# // Solution
#
# (2, 2, 4) => (2, 2, 5)
# (5, 4, 9) => (5, 4, 10)

# %% [markdown]
# # 8
#
# $
#     \begin{align}
#         u + v + w &= 2 \\
#         u + 2v + 3w &= 1 \\
#         v + 2w &= 0
#     \end{align}
# $
#
# v = -2w
#
# u = w
#
# w - 4w + 3w = 1
#
# w + 2(c - 2w) + 3w = 1
#
# 2c = 1
#
# ==> c = $\frac{1}{2}$

# %% [markdown]
# # 9
